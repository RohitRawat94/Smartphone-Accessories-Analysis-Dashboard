# %%
import pandas as pd
mobile_data = pd.read_csv("C:/Users/rawat/OneDrive/Documents/SMARTPHONE RETAIL OUTLET SALE DATA.csv")

# %%
mobile_data
# Out:
#             Date        F.Y  QUARTER     P_NO     PAYMENT TYPE  \
# 0     01-04-2018  2018-2019        1   P/A/36             CASH
# 1     01-04-2018  2018-2019        1   P/A/47             CASH
# 2     01-04-2018  2018-2019        1  P/M/A34           CREDIT
# 3     01-04-2018  2018-2019        1  P/M/A42           CREDIT
# 4     01-04-2018  2018-2019        1  P/M/A42            DEBIT
# ...          ...        ...      ...      ...              ...
# 6416  11-07-2021  2021-2022        2  P/M/A64  MOBILE PAYMENTS
# 6417  12-07-2021  2021-2022        2  P/M/A64             CASH
# 6418  14-07-2021  2021-2022        2  P/M/A64            DEBIT
# 6419  14-07-2021  2021-2022        2  P/M/A64           CREDIT
# 6420  14-07-2021  2021-2022        2  P/M/A64            DEBIT
#
#      TYPE OF PRODUCT  Quantity     Price    Amount TYPE OF ACCESSORY/MOBILE
# 0          ACCESSORY         1   2042.38   2542.38                    COVER
# ...

# %%
mobile_data.head(10)
# Out:
#          Date        F.Y  QUARTER PRODUCT NO     PAYMENT TYPE  \
# 0  01-04-2018  2018-2019        1     P/A/36             CASH
# 1  01-04-2018  2018-2019        1     P/A/47             CASH
# 2  01-04-2018  2018-2019        1    P/M/A34           CREDIT
# 3  01-04-2018  2018-2019        1    P/M/A42           CREDIT
# 4  01-04-2018  2018-2019        1    P/M/A42            DEBIT
# 5  01-04-2018  2018-2019        1    P/M/A43  MOBILE PAYMENTS
# 6  02-04-2018  2018-2019        1    P/M/A19  MOBILE PAYMENTS
# 7  02-04-2018  2018-2019        1    P/M/A34            DEBIT
# 8  02-04-2018  2018-2019        1    P/M/A43           CREDIT
# 9  03-04-2018  2018-2019        1     P/A/47             CASH
#
#   PRODUCT CATEGORY  QUANTITY    PRICE    AMOUNT    PRODUCT SUB-CATEGORY
# 0        ACCESSORY         1  2042.38   2542.38                   COVER
# 1        ACCESSORY         1  2042.38   2118.64        WIRELESS HEADSET
# ...

# %%
mobile_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6421 entries, 0 to 6420
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  6421 non-null   object
#  1   F.Y                   6421 non-null   object
#  2   QUARTER               6421 non-null   int64
#  3   PRODUCT NO            6420 non-null   object
#  4   PAYMENT TYPE          6421 non-null   object
#  5   PRODUCT CATEGORY      6421 non-null   object
#  6   QUANTITY              6421 non-null   int64
#  7   PRICE                 6421 non-null   float64
#  8   AMOUNT                6421 non-null   float64
#  9   PRODUCT SUB-CATEGORY  6421 non-null   object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 501.8+ KB

# %%
pd.isnull(mobile_data)
# Out:
#        Date    F.Y  QUARTER   P_NO  PAYMENT TYPE  TYPE OF PRODUCT  Quantity  \
# 0     False  False    False  False         False            False     False
# 1     False  False    False  False         False            False     False
# 2     False  False    False  False         False            False     False
# 3     False  False    False  False         False            False     False
# 4     False  False    False  False         False            False     False
# ...     ...    ...      ...    ...           ...              ...       ...
# 6416  False  False    False  False         False            False     False
# 6417  False  False    False  False         False            False     False
# 6418  False  False    False  False         False            False     False
# 6419  False  False    False  False         False            False     False
# 6420  False  False    False  False         False            False     False
#
#       Price  Amount  TYPE OF ACCESSORY/MOBILE
# ...

# %%
pd.isnull(mobile_data).sum()
# Out:
# Date                    0
# F.Y                     0
# QUARTER                 0
# PRODUCT NO              1
# PAYMENT TYPE            0
# PRODUCT CATEGORY        0
# QUANTITY                0
# PRICE                   0
# AMOUNT                  0
# PRODUCT SUB-CATEGORY    0
# dtype: int64

# %%
mobile_data.rename(columns={"TYPE OF PRODUCT":"PRODUCT"})
# Out:
#             Date        F.Y  QUARTER     P_NO     PAYMENT TYPE    PRODUCT  \
# 0     01-04-2018  2018-2019        1   P/A/36             CASH  ACCESSORY
# 1     01-04-2018  2018-2019        1   P/A/47             CASH  ACCESSORY
# 2     01-04-2018  2018-2019        1  P/M/A34           CREDIT     MOBILE
# 3     01-04-2018  2018-2019        1  P/M/A42           CREDIT     MOBILE
# 4     01-04-2018  2018-2019        1  P/M/A42            DEBIT     MOBILE
# ...          ...        ...      ...      ...              ...        ...
# 6416  11-07-2021  2021-2022        2  P/M/A64  MOBILE PAYMENTS     MOBILE
# 6417  12-07-2021  2021-2022        2  P/M/A64             CASH     MOBILE
# 6418  14-07-2021  2021-2022        2  P/M/A64            DEBIT     MOBILE
# 6419  14-07-2021  2021-2022        2  P/M/A64           CREDIT     MOBILE
# 6420  14-07-2021  2021-2022        2  P/M/A64            DEBIT     MOBILE
#
#       Quantity     Price    Amount TYPE OF ACCESSORY/MOBILE
# ...

# %%
mobile_data = mobile_data.rename(columns={"P_NO":"PRODUCT NO"})

# %%
mobile_data.head()
# Out:
#          Date        F.Y  QUARTER PRODUCT NO PAYMENT TYPE TYPE OF PRODUCT  \
# 0  01-04-2018  2018-2019        1     P/A/36         CASH       ACCESSORY
# 1  01-04-2018  2018-2019        1     P/A/47         CASH       ACCESSORY
# 2  01-04-2018  2018-2019        1    P/M/A34       CREDIT          MOBILE
# 3  01-04-2018  2018-2019        1    P/M/A42       CREDIT          MOBILE
# 4  01-04-2018  2018-2019        1    P/M/A42        DEBIT          MOBILE
#
#    Quantity    Price    Amount TYPE OF ACCESSORY/MOBILE
# 0         1  2042.38   2542.38                    COVER
# 1         1  2042.38   2118.64         WIRELESS HEADSET
# 2         1  2042.38  13303.58             BUDGET PHONE
# 3         1  2042.38  51696.43           FLAGSHIP PHONE
# 4         1  2042.38  51696.42           FLAGSHIP PHONE

# %%
mobile_data = mobile_data.rename(columns={"TYPE OF PRODUCT":"PRODUCT CATEGORY"})

# %%
mobile_data.describe()
# Out:
#            QUARTER     Quantity          Price         Amount
# count  6421.000000  6421.000000    6421.000000    6421.000000
# mean      2.249338     1.058246   18295.175739   19255.968355
# std       1.000452     0.949686   19855.194755   20608.895584
# min       1.000000     1.000000     410.710000     915.260000
# 25%       1.000000     1.000000    5026.780000    5892.860000
# 50%       2.000000     1.000000   13776.780000   14284.820000
# 75%       3.000000     1.000000   20919.640000   21419.640000
# max       4.000000    30.000000  104767.860000  230803.570000

# %%
mobile_data = mobile_data.rename(columns={"TYPE OF ACCESSORY/MOBILE":"PRODUCT SUB-CATEGORY"})

# %%
mobile_data
# Out:
#             Date        F.Y  QUARTER PRODUCT NO     PAYMENT TYPE  \
# 0     01-04-2018  2018-2019        1     P/A/36             CASH
# 1     01-04-2018  2018-2019        1     P/A/47             CASH
# 2     01-04-2018  2018-2019        1    P/M/A34           CREDIT
# 3     01-04-2018  2018-2019        1    P/M/A42           CREDIT
# 4     01-04-2018  2018-2019        1    P/M/A42            DEBIT
# ...          ...        ...      ...        ...              ...
# 6416  11-07-2021  2021-2022        2    P/M/A64  MOBILE PAYMENTS
# 6417  12-07-2021  2021-2022        2    P/M/A64             CASH
# 6418  14-07-2021  2021-2022        2    P/M/A64            DEBIT
# 6419  14-07-2021  2021-2022        2    P/M/A64           CREDIT
# 6420  14-07-2021  2021-2022        2    P/M/A64            DEBIT
#
#      PRODUCT CATEGORY  Quantity     Price    Amount PRODUCT SUB-CATEGORY
# 0           ACCESSORY         1   2042.38   2542.38                COVER
# ...

# %%
mobile_data = mobile_data.rename(columns={"Quantity":"QUANTITY"})

# %%
mobile_data = mobile_data.rename(columns={"Price":"PRICE"})

# %%
mobile_data = mobile_data.rename(columns={"Amount":"AMOUNT"})

# %%
mobile_data
# Out:
#             Date        F.Y  QUARTER PRODUCT NO     PAYMENT TYPE  \
# 0     01-04-2018  2018-2019        1     P/A/36             CASH
# 1     01-04-2018  2018-2019        1     P/A/47             CASH
# 2     01-04-2018  2018-2019        1    P/M/A34           CREDIT
# 3     01-04-2018  2018-2019        1    P/M/A42           CREDIT
# 4     01-04-2018  2018-2019        1    P/M/A42            DEBIT
# ...          ...        ...      ...        ...              ...
# 6416  11-07-2021  2021-2022        2    P/M/A64  MOBILE PAYMENTS
# 6417  12-07-2021  2021-2022        2    P/M/A64             CASH
# 6418  14-07-2021  2021-2022        2    P/M/A64            DEBIT
# 6419  14-07-2021  2021-2022        2    P/M/A64           CREDIT
# 6420  14-07-2021  2021-2022        2    P/M/A64            DEBIT
#
#      PRODUCT CATEGORY  QUANTITY     PRICE    AMOUNT PRODUCT SUB-CATEGORY
# 0           ACCESSORY         1   2042.38   2542.38                COVER
# ...

# %%
#Changing date into date time format
mobile_data['Date'] = pd.to_datetime(mobile_data['Date'], format='%d/%m/%Y')

# %%
mobile_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6421 entries, 0 to 6420
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  6421 non-null   datetime64[ns]
#  1   F.Y                   6421 non-null   object
#  2   QUARTER               6421 non-null   int64
#  3   PRODUCT NO            6420 non-null   object
#  4   PAYMENT TYPE          6421 non-null   object
#  5   PRODUCT CATEGORY      6421 non-null   object
#  6   QUANTITY              6421 non-null   int64
#  7   PRICE                 6421 non-null   float64
#  8   AMOUNT                6421 non-null   float64
#  9   PRODUCT SUB-CATEGORY  6421 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(5)
# memory usage: 501.8+ KB

# %%
mobile_data=mobile_data.dropna()

# %%
pd.isnull(mobile_data).sum()
# Out:
# Date                    0
# F.Y                     0
# QUARTER                 0
# PRODUCT NO              0
# PAYMENT TYPE            0
# PRODUCT CATEGORY        0
# QUANTITY                0
# PRICE                   0
# AMOUNT                  0
# PRODUCT SUB-CATEGORY    0
# dtype: int64

# %%
#To download Cleaned data
mobile_data.to_csv("phone_data.csv", index=False)
